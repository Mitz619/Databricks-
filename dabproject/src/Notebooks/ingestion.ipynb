# %%
dbutils.widgets.text("catalog_name", "")

# %%
catalog_name = dbutils.widgets.get("catalog_name")

# %%
# See all available catalogs
spark.sql("SHOW CATALOGS").show()

# %%
df = spark.sql(
    f"SELECT * FROM {catalog_name}.information_schema.columns"
)
display(df)

# %%
# %sql
SELECT * FROM assetbundles.information_schema.columns

# %%
# Set catalog_name to a valid catalog, e.g., 'main'

df = spark.sql(
    f"SELECT * FROM {catalog_name}.information_schema.columns"
)
display(df)
